# %% [markdown]
# Charles Haithcock
#
# 18 September 2016
#
# Chirkova, Graph Data Mining
#
# Project 1
#
# # Network Properties in Spark GraphFrames
#
# ### Degree Distribution
#
#
#
# amazon.graph.small
#
#     +------+-----+
#     |degree|count|
#     +------+-----+
#     |     1|  428|
#     |     2|  402|
#     |     3|  350|
#     |     4|  314|
#     |     5|  239|
#     |     6|  133|
#     |     7|   68|
#     |     8|   44|
#     |     9|   27|
#     |    10|   29|
#     |    11|   14|
#     |    12|   12|
#     |    13|    7|
#     |    14|    8|
#     |    15|    2|
#     |    16|    3|
#     |    17|    2|
#     |    18|    2|
#     |    20|    1|
#     +------+-----+
#
# dblp.graph.small
#
#     +------+-----+
#     |degree|count|
#     +------+-----+
#     |     1|  444|
#     |     2|  476|
#     |     3|  419|
#     |     4|  328|
#     |     5|  246|
#     |     6|  113|
#     |     7|   46|
#     |     8|   27|
#     |     9|   16|
#     |    10|    9|
#     |    11|    8|
#     |    12|    8|
#     |    13|    6|
#     |    14|    3|
#     |    15|    1|
#     +------+-----+
#
# youtube.graph.small:
#
#     +------+-----+
#     |degree|count|
#     +------+-----+
#     |     1| 1386|
#     |     2|  188|
#     |     3|   53|
#     |     4|   16|
#     |     5|    4|
#     |     6|    1|
#     |    11|    1|
#     +------+-----+
